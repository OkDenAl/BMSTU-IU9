# %%
using Pkg
Pkg.add(["Images", "ImageIO", "FileIO", "Random", "ProgressMeter", "Plots", "Colors", "Statistics"])
# Out:
#     Updating registry at `~/.julia/registries/General`
#     Updating git-repo `https://github.com/JuliaRegistries/General.git`
#    Resolving package versions...
#    Installed JpegTurbo_jll ──────────────────── v3.1.1+0
#    Installed Libmount_jll ───────────────────── v2.41.0+0
#    Installed ImageSegmentation ──────────────── v1.8.1
#    Installed ImageIO ────────────────────────── v0.6.8
#    Installed TiledIteration ─────────────────── v0.5.0
#    Installed AxisArrays ─────────────────────── v0.4.7
#    Installed OffsetArrays ───────────────────── v1.16.0
#    Installed TiffImages ─────────────────────── v0.10.2
#    Installed LERC_jll ───────────────────────── v4.0.1+0
#    Installed GR_jll ─────────────────────────── v0.73.13+0
#    Installed FFTW ───────────────────────────── v1.8.1
#    Installed HistogramThresholding ──────────── v0.3.1
#    Installed PNGFiles ───────────────────────── v0.4.4
#    Installed JpegTurbo ──────────────────────── v0.1.6
#    Installed ImageMagick ────────────────────── v1.2.1
#    Installed Accessors ──────────────────────── v0.1.42
#    Installed Xorg_xkbcomp_jll ───────────────── v1.4.6+1
#    Installed LoggingExtras ──────────────────── v1.1.0
#    Installed Sixel ──────────────────────────── v0.1.3
#    Installed ConcurrentUtilities ────────────── v2.5.0
#    Installed RegionTrees ────────────────────── v0.3.2
#    Installed Unitful ────────────────────────── v1.22.0
#    Installed StaticArrays ───────────────────── v1.9.13
#    Installed OpenEXR ────────────────────────── v0.3.3
#    Installed PlotUtils ──────────────────────── v1.4.3
#    Installed ProgressMeter ──────────────────── v1.10.2
#    Installed Images ─────────────────────────── v0.26.1
#    Installed CEnum ──────────────────────────── v0.5.0
#    Installed Xorg_libpthread_stubs_jll ──────── v0.1.2+0
#    Installed libsodium_jll ──────────────────── v1.0.21+0
#    Installed Cairo_jll ──────────────────────── v1.18.4+0
#    Installed Fontconfig_jll ─────────────────── v2.16.0+0
#    Installed Libgpg_error_jll ───────────────── v1.51.1+0
#    Installed IntelOpenMP_jll ────────────────── v2025.0.4+0
#    Installed Xorg_libxkbfile_jll ────────────── v1.1.2+1
#    Installed MetaGraphs ─────────────────────── v0.7.2
#    Installed HTTP ───────────────────────────── v1.10.15
#    Installed NearestNeighbors ───────────────── v0.4.21
#    Installed Xorg_libXinerama_jll ───────────── v1.1.5+0
#    Installed Netpbm ─────────────────────────── v1.1.1
#    Installed Static ─────────────────────────── v1.2.0
#    Installed Xorg_libXau_jll ────────────────── v1.0.12+0
#    Installed EpollShim_jll ──────────────────── v0.0.20230411+1
#    Installed SLEEFPirates ───────────────────── v0.6.43
#    Installed Polynomials ────────────────────── v4.0.19
#    Installed Distances ──────────────────────── v0.10.12
#    Installed RealDot ────────────────────────── v0.1.0
#    Installed FFMPEG ─────────────────────────── v0.4.2
#    Installed SIMDTypes ──────────────────────── v0.1.0
#    Installed SIMD ───────────────────────────── v3.7.1
#    Installed IrrationalConstants ────────────── v0.2.4
#    Installed FileIO ─────────────────────────── v1.17.0
#    Installed JLD2 ───────────────────────────── v0.4.54
#    Installed ArnoldiMethod ──────────────────── v0.4.0
#    Installed Pango_jll ──────────────────────── v1.56.1+0
#    Installed CpuId ──────────────────────────── v0.3.1
#    Installed xkbcommon_jll ──────────────────── v1.4.1+2
#    Installed PtrArrays ──────────────────────── v1.3.0
#    Installed Bzip2_jll ──────────────────────── v1.0.9+0
#    Installed QOI ────────────────────────────── v1.0.1
#    Installed SimpleBufferStream ─────────────── v1.2.0
#    Installed XZ_jll ─────────────────────────── v5.8.0+0
#    Installed HarfBuzz_jll ───────────────────── v8.5.0+0
#    Installed IfElse ─────────────────────────── v0.1.1
#    Installed PlotThemes ─────────────────────── v3.3.0
#    Installed PkgVersion ─────────────────────── v0.3.3
#    Installed LZO_jll ────────────────────────── v2.10.3+0
#    Installed NaNMath ────────────────────────── v1.1.3
#    Installed ThreadingUtilities ─────────────── v0.5.2
#    Installed FriBidi_jll ────────────────────── v1.0.16+0
#    Installed fzf_jll ────────────────────────── v0.56.3+0
#    Installed ManualMemory ───────────────────── v0.1.8
#    Installed ZeroMQ_jll ─────────────────────── v4.3.6+0
#    Installed CustomUnitRanges ───────────────── v1.0.2
#    Installed Graphics ───────────────────────── v1.1.3
#    Installed TranscodingStreams ─────────────── v0.11.3
#    Installed GLFW_jll ───────────────────────── v3.4.0+2
#    Installed ImageMetadata ──────────────────── v0.9.9
#    Installed Ratios ─────────────────────────── v0.4.5
#    Installed ComputationalResources ─────────── v0.3.2
#    Installed CatIndices ─────────────────────── v0.2.2
#    Installed Graphs ─────────────────────────── v1.12.1
#    Installed MappedArrays ───────────────────── v0.4.2
#    Installed FreeType2_jll ──────────────────── v2.13.4+0
#    Installed ImageMagick_jll ────────────────── v6.9.13+0
#    Installed JLFzf ──────────────────────────── v0.1.10
#    Installed DataStructures ─────────────────── v0.18.22
#    Installed PaddedViews ────────────────────── v0.5.12
#    Installed CommonWorldInvalidations ───────── v1.0.0
#    Installed LazyModules ────────────────────── v0.3.1
#    Installed CodecZlib ──────────────────────── v0.7.8
#    Installed StaticArrayInterface ───────────── v1.8.0
#    Installed ImageTransformations ───────────── v0.10.1
#    Installed Xorg_libxcb_jll ────────────────── v1.17.0+3
#    Installed MosaicViews ────────────────────── v0.3.4
#    Installed libpng_jll ─────────────────────── v1.6.47+0
#    Installed libaom_jll ─────────────────────── v3.11.0+0
#    Installed ExceptionUnwrapping ────────────── v0.1.11
#    Installed StatsBase ──────────────────────── v0.34.4
#    Installed gperf_jll ──────────────────────── v3.1.1+1
#    Installed ImageCorners ───────────────────── v0.1.3
#    Installed BitTwiddlingConvenienceFunctions ─ v0.1.6
#    Installed oneTBB_jll ─────────────────────── v2022.0.0+0
#    Installed LayoutPointers ─────────────────── v0.1.17
#    Installed Xorg_libXext_jll ───────────────── v1.3.6+3
#    Installed Zstd_jll ───────────────────────── v1.5.7+1
#    Installed JSON3 ──────────────────────────── v1.14.2
#    Installed Expat_jll ──────────────────────── v2.6.5+0
#    Installed ZMQ ────────────────────────────── v1.4.0
#    Installed Inflate ────────────────────────── v0.1.5
#    Installed ImageCore ──────────────────────── v0.9.4
#    Installed Clustering ─────────────────────── v0.15.8
#    Installed Imath_jll ──────────────────────── v3.1.11+0
#    Installed ImageShow ──────────────────────── v0.3.8
#    Installed ImageQualityIndexes ────────────── v0.3.7
#    Installed GR ─────────────────────────────── v0.73.13
#    Installed IntegralArrays ─────────────────── v0.1.6
#    Installed MKL_jll ────────────────────────── v2025.0.1+1
#    Installed Setfield ───────────────────────── v1.1.2
#    Installed Libtiff_jll ────────────────────── v4.7.1+0
#    Installed JLLWrappers ────────────────────── v1.7.0
#    Installed AbstractFFTs ───────────────────── v1.5.0
#    Installed LoopVectorization ──────────────── v0.12.172
#    Installed Libffi_jll ─────────────────────── v3.2.2+2
#    Installed Xorg_libXrender_jll ────────────── v0.9.11+1
#    Installed ColorVectorSpace ───────────────── v0.9.10
#    Installed CoordinateTransformations ──────── v0.6.4
#    Installed OrderedCollections ─────────────── v1.8.0
#    Installed Xorg_libXi_jll ─────────────────── v1.8.2+0
#    Installed ChainRulesCore ─────────────────── v1.25.1
#    Installed XSLT_jll ───────────────────────── v1.1.43+0
#    Installed PolyesterWeave ─────────────────── v0.2.2
#    Installed ArrayInterface ─────────────────── v7.18.0
#    Installed Ghostscript_jll ────────────────── v9.55.0+4
#    Installed StackViews ─────────────────────── v0.1.1
#    Installed AliasTables ────────────────────── v1.1.3
#    Installed LogExpFunctions ────────────────── v0.3.29
#    Installed CloseOpenIntervals ─────────────── v0.1.13
#    Installed LittleCMS_jll ──────────────────── v2.16.0+0
#    Installed Quaternions ────────────────────── v0.7.6
#    Installed MacroTools ─────────────────────── v0.5.15
#    Installed FFTW_jll ───────────────────────── v3.3.11+0
#    Installed RangeArrays ────────────────────── v0.3.2
#    Installed OpenSpecFun_jll ────────────────── v0.5.6+0
#    Installed Xorg_libXcursor_jll ────────────── v1.2.3+0
#    Installed Libuuid_jll ────────────────────── v2.41.0+0
#    Installed Rotations ──────────────────────── v1.7.1
#    Installed SimpleTraits ───────────────────── v0.9.4
#    Installed DocStringExtensions ────────────── v0.9.4
#    Installed OpenEXR_jll ────────────────────── v3.2.4+0
#    Installed Wayland_protocols_jll ──────────── v1.36.0+0
#    Installed Xorg_libICE_jll ────────────────── v1.1.2+0
#    Installed Adapt ──────────────────────────── v4.3.0
#    Installed StableRNGs ─────────────────────── v1.0.2
#    Installed Graphite2_jll ──────────────────── v1.3.15+0
#    Installed Pixman_jll ─────────────────────── v0.44.2+0
#    Installed XML2_jll ───────────────────────── v2.13.6+1
#    Installed ImageBase ──────────────────────── v0.1.5
#    Installed IntervalSets ───────────────────── v0.7.10
#    Installed VectorizationBase ──────────────── v0.21.71
#    Installed Wayland_jll ────────────────────── v1.21.0+2
#    Installed Interpolations ─────────────────── v0.15.1
#    Installed Xorg_xtrans_jll ────────────────── v1.6.0+0
#    Installed Latexify ───────────────────────── v0.16.6
#    Installed OpenJpeg_jll ───────────────────── v2.5.4+0
#    Installed OpenSSL_jll ────────────────────── v3.0.16+0
#    Installed IterTools ──────────────────────── v1.10.0
#    Installed Libgcrypt_jll ──────────────────── v1.11.1+0
#    Installed LLVMOpenMP_jll ─────────────────── v18.1.7+0
#    Installed CPUSummary ─────────────────────── v0.2.6
#    Installed SimpleWeightedGraphs ───────────── v1.5.0
#    Installed IndirectArrays ─────────────────── v1.0.0
#    Installed Xorg_libXrandr_jll ─────────────── v1.5.4+0
#    Installed ImageDistances ─────────────────── v0.2.17
#    Installed Libiconv_jll ───────────────────── v1.18.0+0
#    Installed Xorg_libXfixes_jll ─────────────── v6.0.0+0
#    Installed HostCPUFeatures ────────────────── v0.1.17
#    Installed URIs ───────────────────────────── v1.5.2
#    Installed LaTeXStrings ───────────────────── v1.4.0
#    Installed Glib_jll ───────────────────────── v2.82.4+0
#    Installed libsixel_jll ───────────────────── v1.10.5+0
#    Installed ImageBinarization ──────────────── v0.3.1
#    Installed Libglvnd_jll ───────────────────── v1.7.0+0
#    Installed AxisAlgorithms ─────────────────── v1.1.0
#    Installed ImageAxes ──────────────────────── v0.6.11
#    Installed Requires ───────────────────────── v1.3.1
#    Installed Xorg_libXdmcp_jll ──────────────── v1.1.5+0
#    Installed Xorg_libX11_jll ────────────────── v1.8.6+3
#    Installed FFTViews ───────────────────────── v0.3.2
#    Installed WoodburyMatrices ───────────────── v1.0.0
#    Installed ImageMorphology ────────────────── v0.4.6
#    Installed ImageFiltering ─────────────────── v0.7.6
#    Installed ImageContrastAdjustment ────────── v0.3.12
#     Updating `~/.julia/environments/v1.10/Project.toml`
# ⌅ [5ae59095] + Colors v0.12.11
#   [5789e2e9] + FileIO v1.17.0
# ⌃ [82e4d734] + ImageIO v0.6.8
# ⌃ [916415d5] + Images v0.26.1
#   [92933f4c] + ProgressMeter v1.10.2
#   [9a3f8284] + Random
#   [10745b16] + Statistics v1.10.0
#     Updating `~/.julia/environments/v1.10/Manifest.toml`
#   [621f4979] + AbstractFFTs v1.5.0
#   [7d9f7c33] ↑ Accessors v0.1.41 ⇒ v0.1.42
#   [79e6a3ab] + Adapt v4.3.0
#   [66dad0bd] + AliasTables v1.1.3
#   [ec485272] + ArnoldiMethod v0.4.0
#   [4fba245c] + ArrayInterface v7.18.0
#   [13072b0f] + AxisAlgorithms v1.1.0
#   [39de3d68] + AxisArrays v0.4.7
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.6
#   [fa961155] + CEnum v0.5.0
#   [2a0fbf3d] + CPUSummary v0.2.6
#   [aafaddc9] + CatIndices v0.2.2
#   [d360d2e6] + ChainRulesCore v1.25.1
#   [fb6a15b2] + CloseOpenIntervals v0.1.13
#   [aaaa29a8] + Clustering v0.15.8
#   [944b1d66] ↑ CodecZlib v0.7.6 ⇒ v0.7.8
# ⌅ [c3611d14] ↓ ColorVectorSpace v0.10.0 ⇒ v0.9.10
#   [f70d9fcc] + CommonWorldInvalidations v1.0.0
#   [ed09eef8] + ComputationalResources v0.3.2
#   [f0e56b4a] ↑ ConcurrentUtilities v2.4.2 ⇒ v2.5.0
#   [150eb455] + CoordinateTransformations v0.6.4
#   [adafc99b] + CpuId v0.3.1
#   [dc8bdbbb] + CustomUnitRanges v1.0.2
#   [864edb3b] ↑ DataStructures v0.18.20 ⇒ v0.18.22
#   [b4f34e82] + Distances v0.10.12
#   [ffbed154] ↑ DocStringExtensions v0.9.3 ⇒ v0.9.4
#   [460bff9d] ↑ ExceptionUnwrapping v0.1.10 ⇒ v0.1.11
#   [c87230d0] ↑ FFMPEG v0.4.1 ⇒ v0.4.2
#   [4f61f5a4] + FFTViews v0.3.2
#   [7a1cc6ca] + FFTW v1.8.1
#   [5789e2e9] + FileIO v1.17.0
#   [28b8d3ca] ↑ GR v0.73.7 ⇒ v0.73.13
#   [a2bd30eb] + Graphics v1.1.3
#   [86223c79] + Graphs v1.12.1
#   [cd3eb016] ↑ HTTP v1.10.8 ⇒ v1.10.15
#   [2c695a8d] + HistogramThresholding v0.3.1
#   [3e5b6fbb] + HostCPUFeatures v0.1.17
#   [615f187c] + IfElse v0.1.1
# ⌃ [2803e5a7] + ImageAxes v0.6.11
# ⌃ [c817782e] + ImageBase v0.1.5
#   [cbc4b850] + ImageBinarization v0.3.1
#   [f332f351] + ImageContrastAdjustment v0.3.12
# ⌅ [a09fc81d] + ImageCore v0.9.4
#   [89d5987c] + ImageCorners v0.1.3
#   [51556ac3] + ImageDistances v0.2.17
# ⌃ [6a3955dd] + ImageFiltering v0.7.6
# ⌃ [82e4d734] + ImageIO v0.6.8
# ⌃ [6218d12a] + ImageMagick v1.2.1
# ⌃ [bc367c6b] + ImageMetadata v0.9.9
#   [787d08f9] + ImageMorphology v0.4.6
#   [2996bd0c] + ImageQualityIndexes v0.3.7
# ⌃ [80713f31] + ImageSegmentation v1.8.1
#   [4e3cecfd] + ImageShow v0.3.8
#   [02fcd773] + ImageTransformations v0.10.1
# ⌃ [916415d5] + Images v0.26.1
#   [9b13fd28] + IndirectArrays v1.0.0
#   [d25df0c9] + Inflate v0.1.5
#   [1d092043] + IntegralArrays v0.1.6
#   [a98d9a8b] + Interpolations v0.15.1
#   [8197267c] + IntervalSets v0.7.10
#   [92d709cd] ↑ IrrationalConstants v0.2.2 ⇒ v0.2.4
#   [c8e1da08] + IterTools v1.10.0
# ⌅ [033835bb] + JLD2 v0.4.54
#   [1019f520] ↑ JLFzf v0.1.8 ⇒ v0.1.10
#   [692b3bcd] ↑ JLLWrappers v1.6.0 ⇒ v1.7.0
#   [0f8b85d8] ↑ JSON3 v1.14.1 ⇒ v1.14.2
#   [b835a17e] + JpegTurbo v0.1.6
#   [b964fa9f] ↑ LaTeXStrings v1.3.1 ⇒ v1.4.0
#   [23fbe1c1] ↑ Latexify v0.16.5 ⇒ v0.16.6
#   [10f19ff3] + LayoutPointers v0.1.17
#   [8cdb02fc] + LazyModules v0.3.1
#   [2ab3a3ac] ↑ LogExpFunctions v0.3.28 ⇒ v0.3.29
#   [e6f89c97] ↑ LoggingExtras v1.0.3 ⇒ v1.1.0
#   [bdcacae8] + LoopVectorization v0.12.172
#   [1914dd2f] ↑ MacroTools v0.5.13 ⇒ v0.5.15
#   [d125e4d3] + ManualMemory v0.1.8
#   [dbb5928d] + MappedArrays v0.4.2
# ⌅ [626554b9] + MetaGraphs v0.7.2
#   [e94cdb99] + MosaicViews v0.3.4
#   [77ba4419] ↑ NaNMath v1.0.2 ⇒ v1.1.3
#   [b8a86587] + NearestNeighbors v0.4.21
#   [f09324ee] + Netpbm v1.1.1
#   [6fe1bfb0] + OffsetArrays v1.16.0
#   [52e1d378] + OpenEXR v0.3.3
#   [bac558e1] ↑ OrderedCollections v1.6.3 ⇒ v1.8.0
#   [f57f5aa1] + PNGFiles v0.4.4
#   [5432bcbf] + PaddedViews v0.5.12
#   [b98c9c47] - Pipe v1.3.0
#   [eebad327] + PkgVersion v0.3.3
#   [ccf2f8ad] ↑ PlotThemes v3.2.0 ⇒ v3.3.0
#   [995b91a9] ↑ PlotUtils v1.4.1 ⇒ v1.4.3
#   [1d0040c9] + PolyesterWeave v0.2.2
#   [f27b6e38] + Polynomials v4.0.19
#   [92933f4c] + ProgressMeter v1.10.2
#   [43287f4e] + PtrArrays v1.3.0
#   [4b34888f] + QOI v1.0.1
#   [94ee1d12] + Quaternions v0.7.6
#   [b3c3ace0] + RangeArrays v0.3.2
#   [c84ed2f1] + Ratios v0.4.5
#   [c1ae055f] + RealDot v0.1.0
#   [dee08c22] + RegionTrees v0.3.2
#   [ae029012] ↑ Requires v1.3.0 ⇒ v1.3.1
#   [6038ab10] + Rotations v1.7.1
#   [fdea26ae] + SIMD v3.7.1
#   [94e857df] + SIMDTypes v0.1.0
#   [476501e8] + SLEEFPirates v0.6.43
#   [efcf1570] + Setfield v1.1.2
#   [777ac1f9] ↑ SimpleBufferStream v1.1.0 ⇒ v1.2.0
#   [699a6c99] + SimpleTraits v0.9.4
#   [47aef6b3] + SimpleWeightedGraphs v1.5.0
#   [45858cf5] + Sixel v0.1.3
#   [860ef19b] + StableRNGs v1.0.2
#   [cae243ae] + StackViews v0.1.1
#   [aedffcd0] + Static v1.2.0
#   [0d7ed370] + StaticArrayInterface v1.8.0
#   [90137ffa] + StaticArrays v1.9.13
#   [2913bbd2] ↑ StatsBase v0.34.3 ⇒ v0.34.4
#   [8290d209] + ThreadingUtilities v0.5.2
# ⌅ [731e570b] + TiffImages v0.10.2
#   [06e1c1a7] + TiledIteration v0.5.0
#   [3bb67fe8] ↑ TranscodingStreams v0.11.2 ⇒ v0.11.3
#   [5c2747f8] ↑ URIs v1.5.1 ⇒ v1.5.2
#   [1986cc42] ↑ Unitful v1.21.0 ⇒ v1.22.0
#   [3d5dd08c] + VectorizationBase v0.21.71
#   [efce3f68] + WoodburyMatrices v1.0.0
#   [c2297ded] ↑ ZMQ v1.3.0 ⇒ v1.4.0
#   [6e34b625] ↑ Bzip2_jll v1.0.8+1 ⇒ v1.0.9+0
#   [83423d85] ↑ Cairo_jll v1.18.0+2 ⇒ v1.18.4+0
#   [2702e6a9] ↑ EpollShim_jll v0.0.20230411+0 ⇒ v0.0.20230411+1
#   [2e619515] ↑ Expat_jll v2.6.2+0 ⇒ v2.6.5+0
#   [f5851436] + FFTW_jll v3.3.11+0
#   [a3f928ae] ↑ Fontconfig_jll v2.13.96+0 ⇒ v2.16.0+0
#   [d7e528f0] ↑ FreeType2_jll v2.13.2+0 ⇒ v2.13.4+0
#   [559328eb] ↑ FriBidi_jll v1.0.14+0 ⇒ v1.0.16+0
#   [0656b61e] ↑ GLFW_jll v3.4.0+1 ⇒ v3.4.0+2
#   [d2c73de3] ↑ GR_jll v0.73.7+0 ⇒ v0.73.13+0
#   [61579ee1] + Ghostscript_jll v9.55.0+4
# ⌃ [7746bdde] ↑ Glib_jll v2.80.2+0 ⇒ v2.82.4+0
#   [3b182d85] ↑ Graphite2_jll v1.3.14+0 ⇒ v1.3.15+0
#   [2e76f6c2] ↑ HarfBuzz_jll v8.3.1+0 ⇒ v8.5.0+0
# ⌅ [c73af94c] + ImageMagick_jll v6.9.13+0
#   [905a6f67] + Imath_jll v3.1.11+0
#   [1d5cc7b8] + IntelOpenMP_jll v2025.0.4+0
#   [aacddb02] ↑ JpegTurbo_jll v3.0.3+0 ⇒ v3.1.1+0
#   [88015f11] ↑ LERC_jll v3.0.0+1 ⇒ v4.0.1+0
#   [1d63c593] ↑ LLVMOpenMP_jll v17.0.6+0 ⇒ v18.1.7+0
#   [dd4b983a] ↑ LZO_jll v2.10.2+0 ⇒ v2.10.3+0
# ⌅ [e9f186c6] ↑ Libffi_jll v3.2.2+1 ⇒ v3.2.2+2
#   [d4300ac3] ↑ Libgcrypt_jll v1.8.11+0 ⇒ v1.11.1+0
#   [7e76a0d4] ↑ Libglvnd_jll v1.6.0+0 ⇒ v1.7.0+0
#   [7add5ba3] ↑ Libgpg_error_jll v1.49.0+0 ⇒ v1.51.1+0
#   [94ce4f54] ↑ Libiconv_jll v1.17.0+0 ⇒ v1.18.0+0
#   [4b2f31a3] ↑ Libmount_jll v2.40.1+0 ⇒ v2.41.0+0
#   [89763e89] ↑ Libtiff_jll v4.5.1+1 ⇒ v4.7.1+0
#   [38a345b3] ↑ Libuuid_jll v2.40.1+0 ⇒ v2.41.0+0
#   [d3a379c0] + LittleCMS_jll v2.16.0+0
#   [856f044c] + MKL_jll v2025.0.1+1
#   [18a262bb] + OpenEXR_jll v3.2.4+0
#   [643b3616] + OpenJpeg_jll v2.5.4+0
#   [458c3c95] ↑ OpenSSL_jll v3.0.15+0 ⇒ v3.0.16+0
#   [efe28fd5] ↑ OpenSpecFun_jll v0.5.5+2 ⇒ v0.5.6+0
#   [36c8627f] ↑ Pango_jll v1.54.1+0 ⇒ v1.56.1+0
#   [30392449] ↑ Pixman_jll v0.43.4+0 ⇒ v0.44.2+0
#   [a2964d1f] ↑ Wayland_jll v1.21.0+1 ⇒ v1.21.0+2
#   [2381bf8a] ↑ Wayland_protocols_jll v1.31.0+0 ⇒ v1.36.0+0
#   [02c8fc9c] ↑ XML2_jll v2.13.3+0 ⇒ v2.13.6+1
#   [aed1982a] ↑ XSLT_jll v1.1.41+0 ⇒ v1.1.43+0
#   [ffd25f8a] ↑ XZ_jll v5.4.6+0 ⇒ v5.8.0+0
#   [f67eecfb] ↑ Xorg_libICE_jll v1.1.1+0 ⇒ v1.1.2+0
#   [4f6342f7] ↑ Xorg_libX11_jll v1.8.6+0 ⇒ v1.8.6+3
#   [0c0b7dd1] ↑ Xorg_libXau_jll v1.0.11+0 ⇒ v1.0.12+0
#   [935fb764] ↑ Xorg_libXcursor_jll v1.2.0+4 ⇒ v1.2.3+0
#   [a3789734] ↑ Xorg_libXdmcp_jll v1.1.4+0 ⇒ v1.1.5+0
#   [1082639a] ↑ Xorg_libXext_jll v1.3.6+0 ⇒ v1.3.6+3
#   [d091e8ba] ↑ Xorg_libXfixes_jll v5.0.3+4 ⇒ v6.0.0+0
#   [a51aa0fd] ↑ Xorg_libXi_jll v1.7.10+4 ⇒ v1.8.2+0
#   [d1454406] ↑ Xorg_libXinerama_jll v1.1.4+4 ⇒ v1.1.5+0
#   [ec84b674] ↑ Xorg_libXrandr_jll v1.5.2+4 ⇒ v1.5.4+0
#   [ea2f1a96] ↑ Xorg_libXrender_jll v0.9.11+0 ⇒ v0.9.11+1
#   [14d82f49] ↑ Xorg_libpthread_stubs_jll v0.1.1+0 ⇒ v0.1.2+0
#   [c7cfdc94] ↑ Xorg_libxcb_jll v1.17.0+0 ⇒ v1.17.0+3
#   [cc61e674] ↑ Xorg_libxkbfile_jll v1.1.2+0 ⇒ v1.1.2+1
#   [35661453] ↑ Xorg_xkbcomp_jll v1.4.6+0 ⇒ v1.4.6+1
#   [c5fb5394] ↑ Xorg_xtrans_jll v1.5.0+0 ⇒ v1.6.0+0
#   [8f1865be] ↑ ZeroMQ_jll v4.3.5+0 ⇒ v4.3.6+0
#   [3161d3a3] ↑ Zstd_jll v1.5.6+0 ⇒ v1.5.7+1
#   [214eeab7] ↑ fzf_jll v0.53.0+0 ⇒ v0.56.3+0
#   [1a1c6b14] ↑ gperf_jll v3.1.1+0 ⇒ v3.1.1+1
#   [a4ae2306] ↑ libaom_jll v3.9.0+0 ⇒ v3.11.0+0
#   [b53b4c65] ↑ libpng_jll v1.6.43+1 ⇒ v1.6.47+0
#   [075b6546] + libsixel_jll v1.10.5+0
#   [a9144af2] ↑ libsodium_jll v1.0.20+0 ⇒ v1.0.21+0
#   [1317d2d5] + oneTBB_jll v2022.0.0+0
#   [d8fb68d0] ↑ xkbcommon_jll v1.4.1+1 ⇒ v1.4.1+2
#   [4af54fe1] + LazyArtifacts
#   [1a1011a3] + SharedArrays
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ CEnum
#   ✓ RangeArrays
#   ✓ IndirectArrays
#   ✓ LazyArtifacts
#   ✓ LaTeXStrings
#   ✓ AbstractFFTs
#   ✓ ConcurrentUtilities
#   ✓ ManualMemory
#   ✓ PkgVersion
#   ✓ IterTools
#   ✓ SharedArrays
#   ✓ OrderedCollections
#   ✓ OffsetArrays
#   ✓ SIMDTypes
#   ✓ RealDot
#   ✓ StableRNGs
#   ✓ Requires
#   ✓ DocStringExtensions
#   ✓ MacroTools
#   ✓ CustomUnitRanges
#   ✓ IntervalSets
#   ✓ SimpleBufferStream
#   ✓ URIs
#   ✓ IrrationalConstants
#   ✓ ProgressMeter
#   ✓ ExceptionUnwrapping
#   ✓ PtrArrays
#   ✓ NaNMath
#   ✓ TranscodingStreams
#   ✓ LazyModules
#   ✓ CpuId
#   ✓ IfElse
#   ✓ Inflate
#   ✓ CommonWorldInvalidations
#   ✓ ChainRulesCore
#   ✓ ComputationalResources
#   ✓ MappedArrays
#   ✓ LoggingExtras
#   ✓ JLLWrappers
#   ✓ WoodburyMatrices
#   ✓ Distances
#   ✓ AbstractFFTs → AbstractFFTsTestExt
#   ✓ ThreadingUtilities
#   ✓ Parameters
#   ✓ Tables
#   ✓ Quaternions
#   ✓ DataStructures
#   ✓ Ratios
#   ✓ JSON3
#   ✓ Adapt
#   ✓ SIMD
#   ✓ CommonSubexpressions
#   ✓ StaticArrays
#   ✓ SimpleTraits
#   ✓ IntervalSets → IntervalSetsRandomExt
#   ✓ FileIO
#   ✓ LogExpFunctions
#   ✓ AliasTables
#   ✓ Latexify
#   ✓ CodecZlib
#   ✓ AbstractFFTs → AbstractFFTsChainRulesCoreExt
#   ✓ Graphics
#   ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#   ✓ OpenSSL_jll
#   ✓ Static
#   ✓ Graphite2_jll
#   ✓ Libmount_jll
#   ✓ EpollShim_jll
#   ✓ Bzip2_jll
#   ✓ LLVMOpenMP_jll
#   ✓ libsodium_jll
#   ✓ Xorg_libICE_jll
#   ✓ Ghostscript_jll
#   ✓ Xorg_libXau_jll
#   ✓ Imath_jll
#   ✓ libfdk_aac_jll
#   ✓ IntelOpenMP_jll
#   ✓ libpng_jll
#   ✓ GLPK_jll
#   ✓ Unitful
#   ✓ LAME_jll
#   ✓ LERC_jll
#   ✓ fzf_jll
#   ✓ JpegTurbo_jll
#   ✓ XZ_jll
#   ✓ mtdev_jll
#   ✓ Ogg_jll
#   ✓ PyCall
#   ✓ Xorg_libXdmcp_jll
#   ✓ gperf_jll
#   ✓ oneTBB_jll
#   ✓ x265_jll
#   ✓ x264_jll
#   ✓ Expat_jll
#   ✓ libaom_jll
#   ✓ Zstd_jll
#   ✓ LZO_jll
#   ✓ Opus_jll
#   ✓ Xorg_xtrans_jll
#   ✓ libevdev_jll
#   ✓ Libgpg_error_jll
#   ✓ Libffi_jll
#   ✓ Libiconv_jll
#   ✓ Wayland_protocols_jll
#   ✓ FFTW_jll
#   ✓ Xorg_libpthread_stubs_jll
#   ✓ Libuuid_jll
#   ✓ FriBidi_jll
#   ✓ OpenSpecFun_jll
#   ✓ AxisAlgorithms
#   ✓ Distances → DistancesSparseArraysExt
#   ✓ Ratios → RatiosFixedPointNumbersExt
#   ✓ SortingAlgorithms
#   ✓ OffsetArrays → OffsetArraysAdaptExt
#   ✓ Adapt → AdaptSparseArraysExt
#   ✓ StaticArrays → StaticArraysStatisticsExt
#   ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#   ✓ Adapt → AdaptStaticArraysExt
#   ✓ StaticArrays → StaticArraysChainRulesCoreExt
#   ✓ IntervalSets → IntervalSetsRecipesBaseExt
#   ✓ ConstructionBase → ConstructionBaseIntervalSetsExt

# %%
using Images, ImageIO, FileIO
using Random, ProgressMeter
using Plots, Colors, Statistics

# Параметры генетического алгоритма
const POPULATION_SIZE = 50
const MUTATION_RATE = 0.1
const MAX_GENERATIONS = 1000
const EPSILON_BOOLEAN = 0.05  # 5% несовпадений
const EPSILON_EUCLIDEAN = 0.1  # 10% от максимального расстояния

"""
Создание эталонного вектора цветов
"""
function create_reference_vector(size::Int)
    return rand(0:255, size*size, 3)
end

"""
Инициализация популяции случайными векторами
"""
function initialize_population(vector_size::Int, pop_size::Int)
    return [rand(0:255, vector_size, 3) for _ in 1:pop_size]
end

"""
Булево расстояние - доля несовпадающих элементов
"""
function boolean_distance(vector1::Array{Int,2}, vector2::Array{Int,2})
    return mean(any(vector1 .!= vector2, dims=2))
end

"""
Евклидово расстояние в десятичной системе
"""
function euclidean_distance(vector1::Array{Int,2}, vector2::Array{Int,2})
    return sqrt(sum((vector1 - vector2).^2)) / (length(vector1) * 255)
end

"""
Выбор родителей методом рулетки
"""
function select_parents(population, fitness, num_parents)
    fitness_inv = 1.0 ./ (fitness .+ 1e-10)  # Инвертируем, т.к. меньше расстояние - лучше
    probs = fitness_inv ./ sum(fitness_inv)
    indices = sample(1:length(population), Weights(probs), num_parents, replace=true)
    return [population[i] for i in indices]
end

"""
Кроссинговер на уровне генов (каждое значение - ген)
"""
function crossover_gene_level(parent1::Array{Int,2}, parent2::Array{Int,2})
    child = copy(parent1)
    mask = rand(size(parent1)...) .< 0.5
    child[mask] = parent2[mask]
    return child
end

"""
Кроссинговер на уровне вектора (весь вектор - ген)
"""
function crossover_vector_level(parent1::Array{Int,2}, parent2::Array{Int,2})
    if rand() < 0.5
        return copy(parent1)
    else
        return copy(parent2)
    end
end

"""
Мутация - случайное изменение значений
"""
function mutate!(vector::Array{Int,2}, rate::Float64)
    mask = rand(size(vector)...) .< rate
    vector[mask] = rand(0:255, count(mask))
    return vector
end

"""
Преобразование вектора в изображение
"""
function vector_to_image(vector::Array{Int,2}, size::Int)
    img = reshape(vector, size, size, 3)
    img = permutedims(img, (2, 1, 3))  # Переставляем оси для правильного отображения
    return RGB.(img[:,:,1] ./ 255, img[:,:,2] ./ 255, img[:,:,3] ./ 255)
end

"""
Запуск генетического алгоритма
"""
function run_genetic_algorithm(size::Int, distance_func::Function, crossover_func::Function, epsilon::Float64)
    reference = create_reference_vector(size)
    vector_size = size * size
    population = initialize_population(vector_size, POPULATION_SIZE)
    
    images = []
    best_fitness_history = Float64[]
    
    p = Progress(MAX_GENERATIONS, desc="Генерации: ")
    for generation in 1:MAX_GENERATIONS
        # Оценка приспособленности
        fitness = [distance_func(ind, reference) for ind in population]
        best_idx = argmin(fitness)
        best_fitness = fitness[best_idx]
        push!(best_fitness_history, best_fitness)
        
        # Сохранение текущего состояния
        if generation % 10 == 0 || generation == MAX_GENERATIONS
            best_image = vector_to_image(population[best_idx], size)
            ref_image = vector_to_image(reference, size)
            
            p1 = plot(ref_image, title="Эталон", axis=nothing, size=(300, 300))
            p2 = plot(best_image, title="Поколение $generation\nРасстояние: $(round(best_fitness, digits=4))", 
                      axis=nothing, size=(300, 300))
            
            p_combined = plot(p1, p2, layout=(1, 2), size=(600, 300))
            push!(images, p_combined)
        end
        
        # Проверка критерия остановки
        if best_fitness < epsilon
            break
        end
        
        # Выбор родителей и создание нового поколения
        new_population = [population[best_idx]]  # Элитизм
        
        while length(new_population) < POPULATION_SIZE
            parents = select_parents(population, fitness, 2)
            child = crossover_func(parents[1], parents[2])
            mutate!(child, MUTATION_RATE)
            push!(new_population, child)
        end
        
        population = new_population
        next!(p)
    end
    
    return images, best_fitness_history, length(best_fitness_history)
end

"""
Сохранение GIF-анимации
"""
function save_gif(images, filename; fps=5)
    anim = @animate for img in images
        plot(img)
    end
    
    gif(anim, filename, fps=fps)
end

"""
Запуск эксперимента с заданными параметрами
"""
function run_experiment(size::Int, distance_name::String, crossover_name::String)
    println("Запуск эксперимента: размер $(size)x$(size), расстояние $distance_name, кроссинговер $crossover_name")
    
    if distance_name == "boolean"
        distance_func = boolean_distance
        epsilon = EPSILON_BOOLEAN
    else
        distance_func = euclidean_distance
        epsilon = EPSILON_EUCLIDEAN
    end
    
    if crossover_name == "gene"
        crossover_func = crossover_gene_level
    else
        crossover_func = crossover_vector_level
    end
    
    images, fitness_history, generations = run_genetic_algorithm(size, distance_func, crossover_func, epsilon)
    
    # Сохранение GIF
    filename = "convergence_$(size)x$(size)_$(distance_name)_$(crossover_name).gif"
    save_gif(images, filename)
    
    return filename, fitness_history, generations
end

# Запуск всех экспериментов
function run_all_experiments()
    sizes = [3, 5, 9, 21]
    distances = [("boolean", "Булево"), ("euclidean", "Евклидово")]
    crossovers = [("gene", "Ген-уровень"), ("vector", "Вектор-уровень")]

    results = Dict()

    for size in sizes
        for (dist_code, dist_name) in distances
            for (cross_code, cross_name) in crossovers
                key = "$(size)x$(size)_$(dist_code)_$(cross_code)"
                gif_file, fitness_history, generations = run_experiment(size, dist_code, cross_code)
                results[key] = Dict(
                    "gif" => gif_file,
                    "fitness" => fitness_history,
                    "generations" => generations,
                    "size" => size,
                    "distance" => dist_name,
                    "crossover" => cross_name
                )
            end
        end
    end

    # Вывод результатов
    for (key, data) in results
        println("Эксперимент: $(data["size"])x$(data["size"]), $(data["distance"]) расстояние, $(data["crossover"]) кроссинговер")
        println("Поколений до сходимости: $(data["generations"])")
        println("Итоговое расстояние: $(round(data["fitness"][end], digits=6))")
        println("GIF-файл: $(data["gif"])")
        println("-" ^ 50)
    end
    
    return results
end

# Запуск всех экспериментов
Random.seed!(42)  # Для воспроизводимости результатов
results = run_all_experiments()
